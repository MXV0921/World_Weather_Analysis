# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests
import gmaps

# Import the API key.
from config import weather_api_key

# %%
#import citipy
from citipy import citipy

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each lat & lng combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to the city list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
#    if (i % 50 == 0 and i >= 50):
#        set_count += 1
#        record_count = 1
#        time.sleep(60)

    # Create endpoint URL with each city.
#    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["main"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hovd
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | birigui
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | jibuti
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | port augusta
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | mgandu
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | banda aceh
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | pacific grove
# Processing Record 18 of Set 1 | palmas
# Processing Record 19 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | bull savanna
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | tramore
# Processing Record 26 of Set 1 | brownfield
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | buribay
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | saldanha
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | abu samrah
# Processing Record 33 of Set 1 | novoagansk
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | khani
# Processing Record 36 of Set 1 | umm lajj
# Processing Record 37 of Set 1 | waitara
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | naze
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | bundaberg
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | schladming
# Processing Record 46 of Set 1 | abha
# Processing Record 47 of Set 1 | guane
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | altay
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | makushino
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | ust-ilimsk
# Processing Record 6 of Set 2 | creel
# Processing Record 7 of Set 2 | colquechaca
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | drezdenko
# Processing Record 10 of Set 2 | basco
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | toulepleu
# City not found. Skipping...
# Processing Record 13 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 2 | pyay
# Processing Record 15 of Set 2 | xadani
# City not found. Skipping...
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | pittsfield
# Processing Record 19 of Set 2 | labuan
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | tezu
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | grindavik
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | maceio
# Processing Record 28 of Set 2 | aykhal
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | shalinskoye
# Processing Record 31 of Set 2 | sao filipe
# Processing Record 32 of Set 2 | los arabos
# Processing Record 33 of Set 2 | suoyarvi
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | ippy
# Processing Record 36 of Set 2 | hualmay
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | kysyl-syr
# Processing Record 39 of Set 2 | nelson bay
# Processing Record 40 of Set 2 | ikwiriri
# Processing Record 41 of Set 2 | itaueira
# Processing Record 42 of Set 2 | neuquen
# Processing Record 43 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | grand gaube
# Processing Record 46 of Set 2 | ngama
# Processing Record 47 of Set 2 | yar-sale
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | ambilobe
# Processing Record 50 of Set 2 | domoni
# Processing Record 1 of Set 3 | kambove
# Processing Record 2 of Set 3 | mazamari
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | sola
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | lavrentiya
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | montepuez
# Processing Record 9 of Set 3 | talnakh
# Processing Record 10 of Set 3 | bilibino
# Processing Record 11 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 3 | hobyo
# Processing Record 13 of Set 3 | marawi
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | verkhnevilyuysk
# Processing Record 16 of Set 3 | kahului
# Processing Record 17 of Set 3 | barrow
# Processing Record 18 of Set 3 | hrodna
# Processing Record 19 of Set 3 | kavaratti
# Processing Record 20 of Set 3 | husavik
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | port lincoln
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | adrar
# Processing Record 25 of Set 3 | te anau
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | dunedin
# Processing Record 28 of Set 3 | broken hill
# Processing Record 29 of Set 3 | qaanaaq
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | berlevag
# Processing Record 34 of Set 3 | tunxi
# City not found. Skipping...
# Processing Record 35 of Set 3 | benguela
# Processing Record 36 of Set 3 | erie
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | palana
# Processing Record 39 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 3 | nerchinskiy zavod
# Processing Record 41 of Set 3 | pangai
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | melbu
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | hasaki
# Processing Record 46 of Set 3 | vredendal
# Processing Record 47 of Set 3 | tsalka
# Processing Record 48 of Set 3 | mount isa
# Processing Record 49 of Set 3 | muros
# Processing Record 50 of Set 3 | dzaoudzi
# Processing Record 1 of Set 4 | ourossogui
# Processing Record 2 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 3 of Set 4 | haimen
# Processing Record 4 of Set 4 | linxia
# Processing Record 5 of Set 4 | madang
# Processing Record 6 of Set 4 | tateyama
# Processing Record 7 of Set 4 | khromtau
# Processing Record 8 of Set 4 | porto novo
# Processing Record 9 of Set 4 | birin
# Processing Record 10 of Set 4 | mindelo
# Processing Record 11 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | chuy
# Processing Record 15 of Set 4 | atar
# Processing Record 16 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 17 of Set 4 | bereda
# Processing Record 18 of Set 4 | constitucion
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | plettenberg bay
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | north branch
# Processing Record 24 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | batticaloa
# Processing Record 28 of Set 4 | tecoanapa
# Processing Record 29 of Set 4 | uray
# Processing Record 30 of Set 4 | imbituba
# Processing Record 31 of Set 4 | fukue
# Processing Record 32 of Set 4 | comodoro rivadavia
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | namibe
# Processing Record 35 of Set 4 | nome
# Processing Record 36 of Set 4 | kaffrine
# Processing Record 37 of Set 4 | lonar
# Processing Record 38 of Set 4 | coihaique
# Processing Record 39 of Set 4 | lishu
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | goderich
# Processing Record 42 of Set 4 | tupancireta
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | sao francisco do sul
# Processing Record 45 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | tapes
# Processing Record 48 of Set 4 | saint-louis
# Processing Record 49 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 4 | sabang
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | la paz
# Processing Record 3 of Set 5 | bandrele
# Processing Record 4 of Set 5 | taikang
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | coquimbo
# Processing Record 7 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 5 | atambua
# Processing Record 9 of Set 5 | moindou
# Processing Record 10 of Set 5 | vestmannaeyjar
# Processing Record 11 of Set 5 | vila
# Processing Record 12 of Set 5 | san joaquin
# Processing Record 13 of Set 5 | gigmoto
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | karimpur
# Processing Record 16 of Set 5 | ketchikan
# Processing Record 17 of Set 5 | kiruna
# Processing Record 18 of Set 5 | champerico
# Processing Record 19 of Set 5 | new norfolk
# Processing Record 20 of Set 5 | half moon bay
# Processing Record 21 of Set 5 | vila franca do campo
# Processing Record 22 of Set 5 | maniitsoq
# Processing Record 23 of Set 5 | conceicao da barra
# Processing Record 24 of Set 5 | waingapu
# Processing Record 25 of Set 5 | russellville
# Processing Record 26 of Set 5 | puksoozero
# Processing Record 27 of Set 5 | port hardy
# Processing Record 28 of Set 5 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 29 of Set 5 | kitimat
# Processing Record 30 of Set 5 | the valley
# Processing Record 31 of Set 5 | mecca
# Processing Record 32 of Set 5 | mehamn
# Processing Record 33 of Set 5 | bosaso
# Processing Record 34 of Set 5 | itarema
# Processing Record 35 of Set 5 | alexandria
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 5 | preobrazheniye
# Processing Record 39 of Set 5 | da lat
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | dikson
# Processing Record 42 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 5 | sandpoint
# Processing Record 44 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 5 | bethanien
# Processing Record 46 of Set 5 | tiksi
# Processing Record 47 of Set 5 | mae sai
# Processing Record 48 of Set 5 | niquero
# Processing Record 49 of Set 5 | colimes
# Processing Record 50 of Set 5 | dicabisagan
# Processing Record 1 of Set 6 | caravelas
# Processing Record 2 of Set 6 | yenagoa
# Processing Record 3 of Set 6 | seoul
# Processing Record 4 of Set 6 | saint-michel-des-saints
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 6 | catalao
# Processing Record 8 of Set 6 | avera
# Processing Record 9 of Set 6 | maun
# Processing Record 10 of Set 6 | igrim
# Processing Record 11 of Set 6 | jackson
# Processing Record 12 of Set 6 | lima
# Processing Record 13 of Set 6 | zarya
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | itaituba
# Processing Record 16 of Set 6 | sann
# Processing Record 17 of Set 6 | koslan
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | flinders
# Processing Record 20 of Set 6 | rizhao
# Processing Record 21 of Set 6 | dorogino
# Processing Record 22 of Set 6 | poum
# Processing Record 23 of Set 6 | sinnamary
# Processing Record 24 of Set 6 | meulaboh
# Processing Record 25 of Set 6 | ola
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | san juan
# Processing Record 28 of Set 6 | ahipara
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | ouro preto do oeste
# Processing Record 31 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 6 | vaitape
# Processing Record 33 of Set 6 | mayo
# Processing Record 34 of Set 6 | kazachinskoye
# Processing Record 35 of Set 6 | bullhead city
# Processing Record 36 of Set 6 | sungaipenuh
# Processing Record 37 of Set 6 | asau
# Processing Record 38 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 39 of Set 6 | tommot
# Processing Record 40 of Set 6 | longyearbyen
# Processing Record 41 of Set 6 | mnogovershinnyy
# Processing Record 42 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 43 of Set 6 | miraflores
# Processing Record 44 of Set 6 | wattegama
# Processing Record 45 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 6 | taltal
# Processing Record 47 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 6 | las palmas
# Processing Record 49 of Set 6 | conde
# Processing Record 50 of Set 6 | sao joao da barra
# Processing Record 1 of Set 7 | belmonte
# Processing Record 2 of Set 7 | ginda
# Processing Record 3 of Set 7 | melfort
# Processing Record 4 of Set 7 | kita
# Processing Record 5 of Set 7 | khasan
# Processing Record 6 of Set 7 | la ronge
# Processing Record 7 of Set 7 | chokurdakh
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | galle
# Processing Record 10 of Set 7 | conceicao do araguaia
# Processing Record 11 of Set 7 | scottsbluff
# Processing Record 12 of Set 7 | amarante
# Processing Record 13 of Set 7 | aranda de duero
# Processing Record 14 of Set 7 | narsaq
# Processing Record 15 of Set 7 | fort nelson
# Processing Record 16 of Set 7 | laguna
# Processing Record 17 of Set 7 | acarau
# Processing Record 18 of Set 7 | glubokoe
# City not found. Skipping...
# Processing Record 19 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 7 | wangqing
# Processing Record 21 of Set 7 | sorland
# Processing Record 22 of Set 7 | westbrook
# Processing Record 23 of Set 7 | los llanos de aridane
# Processing Record 24 of Set 7 | tasiilaq
# Processing Record 25 of Set 7 | tsiroanomandidy
# Processing Record 26 of Set 7 | leshukonskoye
# Processing Record 27 of Set 7 | bonavista
# Processing Record 28 of Set 7 | camargo
# Processing Record 29 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | hervey bay
# Processing Record 31 of Set 7 | vao
# Processing Record 32 of Set 7 | pathein
# Processing Record 33 of Set 7 | shahr-e kord
# Processing Record 34 of Set 7 | petapa
# Processing Record 35 of Set 7 | hambantota
# Processing Record 36 of Set 7 | young
# Processing Record 37 of Set 7 | jalu
# Processing Record 38 of Set 7 | limon
# Processing Record 39 of Set 7 | ariquemes
# Processing Record 40 of Set 7 | malanje
# Processing Record 41 of Set 7 | mardin
# Processing Record 42 of Set 7 | garowe
# Processing Record 43 of Set 7 | boffa
# Processing Record 44 of Set 7 | chapais
# Processing Record 45 of Set 7 | gunjur
# Processing Record 46 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 7 | sroda wielkopolska
# Processing Record 48 of Set 7 | sonaguera
# Processing Record 49 of Set 7 | beringovskiy
# Processing Record 50 of Set 7 | nikopol
# Processing Record 1 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 8 | artyom
# Processing Record 3 of Set 8 | timra
# Processing Record 4 of Set 8 | margate
# Processing Record 5 of Set 8 | majene
# Processing Record 6 of Set 8 | sembe
# Processing Record 7 of Set 8 | pitimbu
# Processing Record 8 of Set 8 | ulaanbaatar
# Processing Record 9 of Set 8 | saint-georges
# Processing Record 10 of Set 8 | vieste
# Processing Record 11 of Set 8 | isangel
# Processing Record 12 of Set 8 | beyneu
# Processing Record 13 of Set 8 | valle hermoso
# Processing Record 14 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 8 | shimoda
# Processing Record 16 of Set 8 | ardino
# Processing Record 17 of Set 8 | halifax
# Processing Record 18 of Set 8 | port townsend
# Processing Record 19 of Set 8 | hay river
# Processing Record 20 of Set 8 | registro
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | zhigansk
# Processing Record 23 of Set 8 | ilek
# Processing Record 24 of Set 8 | erenhot
# Processing Record 25 of Set 8 | lazaro cardenas
# Processing Record 26 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 27 of Set 8 | yulara
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | norman wells
# Processing Record 30 of Set 8 | leningradskiy
# Processing Record 31 of Set 8 | vanimo
# Processing Record 32 of Set 8 | praya
# Processing Record 33 of Set 8 | turayf
# Processing Record 34 of Set 8 | souillac
# Processing Record 35 of Set 8 | ulladulla
# Processing Record 36 of Set 8 | aklavik
# Processing Record 37 of Set 8 | karratha
# Processing Record 38 of Set 8 | mahebourg
# Processing Record 39 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 40 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 8 | trairi
# Processing Record 42 of Set 8 | otaru
# Processing Record 43 of Set 8 | visby
# Processing Record 44 of Set 8 | camacha
# Processing Record 45 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 8 | tombouctou
# Processing Record 47 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 8 | areia branca
# Processing Record 49 of Set 8 | breves
# Processing Record 50 of Set 8 | callaway
# Processing Record 1 of Set 9 | sabzevar
# Processing Record 2 of Set 9 | mercedes
# Processing Record 3 of Set 9 | sarab
# Processing Record 4 of Set 9 | kincardine
# Processing Record 5 of Set 9 | valparaiso
# Processing Record 6 of Set 9 | seminole
# Processing Record 7 of Set 9 | fairbanks
# Processing Record 8 of Set 9 | mae sot
# Processing Record 9 of Set 9 | novo aripuana
# Processing Record 10 of Set 9 | astipalaia
# City not found. Skipping...
# Processing Record 11 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 12 of Set 9 | alugan
# Processing Record 13 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 9 | lagoa
# Processing Record 15 of Set 9 | zyryanka
# Processing Record 16 of Set 9 | aksu
# Processing Record 17 of Set 9 | zambezi
# Processing Record 18 of Set 9 | steamboat springs
# Processing Record 19 of Set 9 | gazni
# City not found. Skipping...
# Processing Record 20 of Set 9 | saint-augustin
# Processing Record 21 of Set 9 | oleksandrivka
# Processing Record 22 of Set 9 | alghero
# Processing Record 23 of Set 9 | culfa
# Processing Record 24 of Set 9 | marfino
# Processing Record 25 of Set 9 | ocos
# Processing Record 26 of Set 9 | saint-pierre
# Processing Record 27 of Set 9 | kawalu
# Processing Record 28 of Set 9 | chunoyar
# Processing Record 29 of Set 9 | wellington
# Processing Record 30 of Set 9 | klaksvik
# Processing Record 31 of Set 9 | nantucket
# Processing Record 32 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 9 | banjar
# Processing Record 34 of Set 9 | cairns
# Processing Record 35 of Set 9 | forio
# Processing Record 36 of Set 9 | nanortalik
# Processing Record 37 of Set 9 | nurota
# Processing Record 38 of Set 9 | auki
# Processing Record 39 of Set 9 | chebarkul
# Processing Record 40 of Set 9 | viedma
# Processing Record 41 of Set 9 | mataram
# Processing Record 42 of Set 9 | quballat
# Processing Record 43 of Set 9 | ishigaki
# Processing Record 44 of Set 9 | ailigandi
# Processing Record 45 of Set 9 | sao felix do xingu
# Processing Record 46 of Set 9 | tank
# Processing Record 47 of Set 9 | annau
# Processing Record 48 of Set 9 | brive-la-gaillarde
# Processing Record 49 of Set 9 | umm kaddadah
# Processing Record 50 of Set 9 | noumea
# Processing Record 1 of Set 10 | port hedland
# Processing Record 2 of Set 10 | punakha
# Processing Record 3 of Set 10 | coxim
# Processing Record 4 of Set 10 | airai
# Processing Record 5 of Set 10 | feicheng
# Processing Record 6 of Set 10 | sambava
# Processing Record 7 of Set 10 | tartagal
# Processing Record 8 of Set 10 | pevek
# Processing Record 9 of Set 10 | juegang
# Processing Record 10 of Set 10 | mahibadhoo
# Processing Record 11 of Set 10 | khovu-aksy
# Processing Record 12 of Set 10 | sal rei
# Processing Record 13 of Set 10 | egvekinot
# Processing Record 14 of Set 10 | rochegda
# Processing Record 15 of Set 10 | xuanzhou
# Processing Record 16 of Set 10 | sri aman
# Processing Record 17 of Set 10 | sur
# Processing Record 18 of Set 10 | namatanai
# Processing Record 19 of Set 10 | jaciara
# Processing Record 20 of Set 10 | sakhnovshchyna
# Processing Record 21 of Set 10 | cabedelo
# Processing Record 22 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 23 of Set 10 | el bagre
# Processing Record 24 of Set 10 | srednekolymsk
# Processing Record 25 of Set 10 | zacualpan
# Processing Record 26 of Set 10 | kudahuvadhoo
# Processing Record 27 of Set 10 | saint anthony
# Processing Record 28 of Set 10 | piacabucu
# Processing Record 29 of Set 10 | takoradi
# Processing Record 30 of Set 10 | san policarpo
# Processing Record 31 of Set 10 | joshimath
# Processing Record 32 of Set 10 | aswan
# Processing Record 33 of Set 10 | sao jose da coroa grande
# Processing Record 34 of Set 10 | huarmey
# Processing Record 35 of Set 10 | ecoporanga
# Processing Record 36 of Set 10 | ebano
# City not found. Skipping...
# Processing Record 37 of Set 10 | poronaysk
# Processing Record 38 of Set 10 | haines junction
# Processing Record 39 of Set 10 | ilulissat
# Processing Record 40 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 10 | atbasar
# Processing Record 42 of Set 10 | ostrovnoy
# Processing Record 43 of Set 10 | vestmanna
# Processing Record 44 of Set 10 | pedana
# Processing Record 45 of Set 10 | sarkand
# Processing Record 46 of Set 10 | peterborough
# Processing Record 47 of Set 10 | virginia beach
# Processing Record 48 of Set 10 | coracao de jesus
# Processing Record 49 of Set 10 | teknaf
# Processing Record 50 of Set 10 | muroto
# Processing Record 1 of Set 11 | smolenka
# Processing Record 2 of Set 11 | havelock
# Processing Record 3 of Set 11 | bambanglipuro
# Processing Record 4 of Set 11 | burla
# Processing Record 5 of Set 11 | kununurra
# Processing Record 6 of Set 11 | arrecife
# Processing Record 7 of Set 11 | noshiro
# Processing Record 8 of Set 11 | huayucachi
# Processing Record 9 of Set 11 | deputatskiy
# Processing Record 10 of Set 11 | tyazhinskiy
# Processing Record 11 of Set 11 | santa maria
# Processing Record 12 of Set 11 | valday
# Processing Record 13 of Set 11 | coracora
# Processing Record 14 of Set 11 | aanekoski
# Processing Record 15 of Set 11 | pitea
# Processing Record 16 of Set 11 | eyrarbakki
# Processing Record 17 of Set 11 | roma
# Processing Record 18 of Set 11 | russell
# Processing Record 19 of Set 11 | tuatapere
# Processing Record 20 of Set 11 | luyang
# Processing Record 21 of Set 11 | hebertville
# City not found. Skipping...
# Processing Record 22 of Set 11 | kurilsk
# Processing Record 23 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 24 of Set 11 | marsa matruh
# Processing Record 25 of Set 11 | portland
# Processing Record 26 of Set 11 | padang
# Processing Record 27 of Set 11 | richards bay
# Processing Record 28 of Set 11 | pirovskoye
# Processing Record 29 of Set 11 | san patricio
# Processing Record 30 of Set 11 | prabumulih
# Processing Record 31 of Set 11 | neepawa
# Processing Record 32 of Set 11 | nove zamky
# Processing Record 33 of Set 11 | puerto del rosario
# Processing Record 34 of Set 11 | nuuk
# Processing Record 35 of Set 11 | arkhangelos
# City not found. Skipping...
# Processing Record 36 of Set 11 | kjollefjord
# Processing Record 37 of Set 11 | battle creek
# Processing Record 38 of Set 11 | payakumbuh
# Processing Record 39 of Set 11 | christchurch
# Processing Record 40 of Set 11 | varzob
# Processing Record 41 of Set 11 | port-cartier
# Processing Record 42 of Set 11 | balakirevo
# Processing Record 43 of Set 11 | jatni
# City not found. Skipping...
# Processing Record 44 of Set 11 | ambon
# Processing Record 45 of Set 11 | lowestoft
# Processing Record 46 of Set 11 | tagusao
# Processing Record 47 of Set 11 | gambela
# Processing Record 48 of Set 11 | hofn
# Processing Record 49 of Set 11 | mirnyy
# Processing Record 50 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 12 | araouane
# Processing Record 2 of Set 12 | anan
# Processing Record 3 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 12 | lucapa
# Processing Record 5 of Set 12 | lompoc
# Processing Record 6 of Set 12 | ayios matthaios
# City not found. Skipping...
# Processing Record 7 of Set 12 | khorixas
# Processing Record 8 of Set 12 | tsogni
# Processing Record 9 of Set 12 | nara
# Processing Record 10 of Set 12 | amapa
# Processing Record 11 of Set 12 | fairlie
# Processing Record 12 of Set 12 | brooks
# Processing Record 13 of Set 12 | octeville
# Processing Record 14 of Set 12 | semey
# Processing Record 15 of Set 12 | clyde river
# Processing Record 16 of Set 12 | voyvozh
# Processing Record 17 of Set 12 | mahanoro
# Processing Record 18 of Set 12 | monrovia
# Processing Record 19 of Set 12 | la fria
# Processing Record 20 of Set 12 | rio claro
# Processing Record 21 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 12 | teya
# Processing Record 23 of Set 12 | lafia
# Processing Record 24 of Set 12 | nakusp
# Processing Record 25 of Set 12 | zhuhai
# Processing Record 26 of Set 12 | wagar
# Processing Record 27 of Set 12 | port-gentil
# Processing Record 28 of Set 12 | port blair
# Processing Record 29 of Set 12 | san ramon de la nueva oran
# Processing Record 30 of Set 12 | yomou
# Processing Record 31 of Set 12 | usinsk
# Processing Record 32 of Set 12 | tura
# Processing Record 33 of Set 12 | carauari
# Processing Record 34 of Set 12 | praia da vitoria
# Processing Record 35 of Set 12 | ayagoz
# Processing Record 36 of Set 12 | wilmington
# Processing Record 37 of Set 12 | ravar
# Processing Record 38 of Set 12 | huescar
# Processing Record 39 of Set 12 | bialystok
# Processing Record 40 of Set 12 | nisia floresta
# Processing Record 41 of Set 12 | manicore
# Processing Record 42 of Set 12 | sari
# Processing Record 43 of Set 12 | pahrump
# Processing Record 44 of Set 12 | benghazi
# Processing Record 45 of Set 12 | snyder
# Processing Record 46 of Set 12 | rocha
# Processing Record 47 of Set 12 | ende
# Processing Record 48 of Set 12 | morant bay
# Processing Record 49 of Set 12 | acajutla
# Processing Record 50 of Set 12 | san cristobal
# Processing Record 1 of Set 13 | inuvik
# Processing Record 2 of Set 13 | thunder bay
# Processing Record 3 of Set 13 | san felipe
# Processing Record 4 of Set 13 | batemans bay
# Processing Record 5 of Set 13 | urengoy
# Processing Record 6 of Set 13 | rawson
# Processing Record 7 of Set 13 | ust-kulom
# Processing Record 8 of Set 13 | maymanak
# City not found. Skipping...
# Processing Record 9 of Set 13 | sisimiut
# Processing Record 10 of Set 13 | jaque
# Processing Record 11 of Set 13 | olafsvik
# Processing Record 12 of Set 13 | galesong
# Processing Record 13 of Set 13 | sterling
# Processing Record 14 of Set 13 | vanavara
# Processing Record 15 of Set 13 | taoudenni
# Processing Record 16 of Set 13 | pochutla
# Processing Record 17 of Set 13 | rovaniemi
# Processing Record 18 of Set 13 | contai
# Processing Record 19 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 13 | beloha
# Processing Record 21 of Set 13 | paluan
# Processing Record 22 of Set 13 | araioses
# Processing Record 23 of Set 13 | kletskaya
# Processing Record 24 of Set 13 | sarangani
# Processing Record 25 of Set 13 | moree
# Processing Record 26 of Set 13 | darhan
# Processing Record 27 of Set 13 | sibu
# Processing Record 28 of Set 13 | concordia
# Processing Record 29 of Set 13 | brae
# Processing Record 30 of Set 13 | labuhan
# Processing Record 31 of Set 13 | vila velha
# Processing Record 32 of Set 13 | nioro
# Processing Record 33 of Set 13 | natal
# Processing Record 34 of Set 13 | marzuq
# Processing Record 35 of Set 13 | drolshagen
# Processing Record 36 of Set 13 | cockburn town
# Processing Record 37 of Set 13 | murdochville
# Processing Record 38 of Set 13 | puerto escondido
# Processing Record 39 of Set 13 | parry sound
# Processing Record 40 of Set 13 | savannah bight
# Processing Record 41 of Set 13 | bakaly
# Processing Record 42 of Set 13 | sitio novo do tocantins
# Processing Record 43 of Set 13 | indianola
# Processing Record 44 of Set 13 | havre-saint-pierre
# Processing Record 45 of Set 13 | nazas
# Processing Record 46 of Set 13 | dubovyy umet
# Processing Record 47 of Set 13 | okato
# Processing Record 48 of Set 13 | yuanping
# Processing Record 49 of Set 13 | nouadhibou
# Processing Record 50 of Set 13 | mwene-ditu
# Processing Record 1 of Set 14 | tahta
# Processing Record 2 of Set 14 | doha
# Processing Record 3 of Set 14 | yarim
# Processing Record 4 of Set 14 | machilipatnam
# Processing Record 5 of Set 14 | mokrousovo
# Processing Record 6 of Set 14 | menongue
# Processing Record 7 of Set 14 | bergerac
# Processing Record 8 of Set 14 | derzhavinsk
# Processing Record 9 of Set 14 | cam ranh
# Processing Record 10 of Set 14 | seymchan
# Processing Record 11 of Set 14 | qunduz
# Processing Record 12 of Set 14 | westport
# Processing Record 13 of Set 14 | tocopilla
# Processing Record 14 of Set 14 | iqaluit
# Processing Record 15 of Set 14 | xiaoweizhai
# Processing Record 16 of Set 14 | elizabeth city
# Processing Record 17 of Set 14 | sturgeon bay
# Processing Record 18 of Set 14 | paka
# Processing Record 19 of Set 14 | parrita
# Processing Record 20 of Set 14 | tchibanga
# Processing Record 21 of Set 14 | rozvadiv
# Processing Record 22 of Set 14 | otradnoye
# Processing Record 23 of Set 14 | hamilton
# Processing Record 24 of Set 14 | malakal
# Processing Record 25 of Set 14 | salme
# Processing Record 26 of Set 14 | surgut
# Processing Record 27 of Set 14 | jacareacanga
# Processing Record 28 of Set 14 | evensk
# Processing Record 29 of Set 14 | sussex
# Processing Record 30 of Set 14 | timmins
# Processing Record 31 of Set 14 | challapata
# Processing Record 32 of Set 14 | bandarbeyla
# Processing Record 33 of Set 14 | omboue
# Processing Record 34 of Set 14 | turukhansk
# Processing Record 35 of Set 14 | gediz
# Processing Record 36 of Set 14 | moron
# Processing Record 37 of Set 14 | alihe
# Processing Record 38 of Set 14 | bontang
# Processing Record 39 of Set 14 | borogontsy
# Processing Record 40 of Set 14 | mana
# Processing Record 41 of Set 14 | daru
# Processing Record 42 of Set 14 | kattivakkam
# Processing Record 43 of Set 14 | phalaborwa
# Processing Record 44 of Set 14 | vardo
# Processing Record 45 of Set 14 | lasa
# Processing Record 46 of Set 14 | kalmunai
# Processing Record 47 of Set 14 | ayan
# Processing Record 48 of Set 14 | togul
# Processing Record 49 of Set 14 | candawaga
# City not found. Skipping...
# Processing Record 50 of Set 14 | navirai
# Processing Record 1 of Set 15 | columbus
# Processing Record 2 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 15 | yushu
# Processing Record 4 of Set 15 | non sang
# Processing Record 5 of Set 15 | pemangkat
# Processing Record 6 of Set 15 | vorobyevka
# Processing Record 7 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 15 | gopalpur
# Processing Record 9 of Set 15 | manggar
# Processing Record 10 of Set 15 | carora
# Processing Record 11 of Set 15 | velsk
# Processing Record 12 of Set 15 | saquarema
# Processing Record 13 of Set 15 | teneguiban
# City not found. Skipping...
# Processing Record 14 of Set 15 | khanpur
# Processing Record 15 of Set 15 | baculin
# Processing Record 16 of Set 15 | college
# Processing Record 17 of Set 15 | panama city
# Processing Record 18 of Set 15 | ust-kut
# Processing Record 19 of Set 15 | kallithea
# Processing Record 20 of Set 15 | maragogi
# Processing Record 21 of Set 15 | vostok
# Processing Record 22 of Set 15 | lofthus
# Processing Record 23 of Set 15 | rio negrinho
# Processing Record 24 of Set 15 | antofagasta
# Processing Record 25 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 15 | outram
# Processing Record 27 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 15 | saint-denis
# Processing Record 29 of Set 15 | marabba
# Processing Record 30 of Set 15 | celestun
# Processing Record 31 of Set 15 | hirara
# Processing Record 32 of Set 15 | gorkovskoye
# City not found. Skipping...
# Processing Record 33 of Set 15 | metu
# Processing Record 34 of Set 15 | henties bay
# Processing Record 35 of Set 15 | wajima
# Processing Record 36 of Set 15 | jumla
# Processing Record 37 of Set 15 | qaqortoq
# Processing Record 38 of Set 15 | the pas
# Processing Record 39 of Set 15 | leeton
# Processing Record 40 of Set 15 | dourbali
# Processing Record 41 of Set 15 | lensk
# Processing Record 42 of Set 15 | skjervoy
# Processing Record 43 of Set 15 | carutapera
# Processing Record 44 of Set 15 | crestview
# Processing Record 45 of Set 15 | bohuslav
# Processing Record 46 of Set 15 | mitha tiwana
# Processing Record 47 of Set 15 | zamora
# Processing Record 48 of Set 15 | devils lake
# Processing Record 49 of Set 15 | marang
# Processing Record 50 of Set 15 | yangjiang
# Processing Record 1 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 16 | uruzgan
# Processing Record 3 of Set 16 | beira
# Processing Record 4 of Set 16 | samatau
# City not found. Skipping...
# Processing Record 5 of Set 16 | lorengau
# Processing Record 6 of Set 16 | balakhninskiy
# Processing Record 7 of Set 16 | sao domingos
# Processing Record 8 of Set 16 | ballina
# Processing Record 9 of Set 16 | kamaishi
# Processing Record 10 of Set 16 | mehtar lam
# Processing Record 11 of Set 16 | kargasok
# Processing Record 12 of Set 16 | xixiang
# Processing Record 13 of Set 16 | chara
# Processing Record 14 of Set 16 | rabo de peixe
# Processing Record 15 of Set 16 | kungurtug
# Processing Record 16 of Set 16 | escanaba
# Processing Record 17 of Set 16 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 16 | pangnirtung
# Processing Record 19 of Set 16 | fukagawa
# Processing Record 20 of Set 16 | yurimaguas
# Processing Record 21 of Set 16 | san luis
# Processing Record 22 of Set 16 | trofors
# Processing Record 23 of Set 16 | chitral
# Processing Record 24 of Set 16 | oum hadjer
# Processing Record 25 of Set 16 | korla
# Processing Record 26 of Set 16 | develi
# Processing Record 27 of Set 16 | goya
# Processing Record 28 of Set 16 | voloshka
# Processing Record 29 of Set 16 | valjala
# City not found. Skipping...
# Processing Record 30 of Set 16 | yilan
# Processing Record 31 of Set 16 | manokwari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hovd  48.0056   91.6419     48.02        31           0
# 1         Kapaa  22.0752 -159.3190     79.12        78          40
# 2       Birigui -21.2886  -50.3400     85.33        33           0
# 3     Jamestown  42.0970  -79.2353     80.06        51          20
# 4        Jibuti  11.5000   42.5000     85.77        41           5
# 5       Ushuaia -54.8000  -68.3000     44.22       100          75
# 6        Hobart -42.8794  147.3294     53.28        90         100
# 7        Atuona  -9.8000 -139.0333     78.12        70          68
# 8  Port Augusta -32.5000  137.7667     66.69        49         100
# 9        Avarua -21.2078 -159.7750     80.65        89         100
#
#    Wind Speed Weather Description Country                 Date
# 0        1.66               Clear      MN  2022-05-13 19:14:51
# 1       13.80              Clouds      US  2022-05-13 19:14:52
# 2        1.68               Clear      BR  2022-05-13 19:14:52
# 3        8.05              Clouds      US  2022-05-13 19:11:14
# 4        8.97               Clear      DJ  2022-05-13 19:14:52
# 5        2.30              Clouds      AR  2022-05-13 19:14:53
# 6        3.44              Clouds      AU  2022-05-13 19:10:10
# 7       20.11              Clouds      PF  2022-05-13 19:14:53
# 8       17.52              Clouds      AU  2022-05-13 19:14:54
# 9       10.36              Clouds      CK  2022-05-13 19:13:13

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="WeatherPy_Database")
